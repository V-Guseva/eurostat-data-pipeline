# %%
import seaborn as sns
import pandas as pd
pd.set_option('display.max_colwidth',None)

# %%
from pathlib import Path

# %%
import eurostat

def load_df_raw_catalog():
    return eurostat.get_toc_df()

# %%
import re

from pandas.core.interchange.dataframe_protocol import DataFrame


def split_domain(code):
    match = re.match(r"^([A-Z]+)+(_)+(.*)",code)
    if match:
        return match.group(1), match.group(3)
    return code

def convert_to_datetime(series):
    cleaned = series.astype('str').str.replace(r'([+-]\d{2}):(\d{2})', r'\1:\2', regex=True)
    return pd.to_datetime(cleaned, errors='coerce', utc=True)

def convert_object_to_category(df:DataFrame, threshold :int=5):
    description = df[df.select_dtypes('object')].describe()
    unique_counts = description.loc['unique']
    for column in unique_counts[unique_counts < threshold].index.tolist():
        df[column] = df[column].astype('category')
    return df

# %% [markdown]
# # Load and explore data

# %%
df_ds = load_df_raw_catalog()

# %%
df_ds.head()
# Out:
#                                                                                                                           title  \
# 0  Employment rate of adults by sex, age groups, educational attainment level, number of children and age of youngest child (%)
# 1  Employment rate of adults by sex, age groups, educational attainment level, number of children and age of youngest child (%)
# 2                                Employment rate by sex, age groups, educational attainment level and household composition (%)
# 3                          Number of persons by sex, age groups, household composition and educational attainment level (1 000)
# 4                                        Number of persons by sex, age groups, household composition and working status (1 000)
#
#                     code     type       last update of data  \
# 0  LFST_HHEREDCH$DV_1904  dataset  2025-04-15T11:00:00+0200
# 1  LFST_HHEREDCH$DV_2683  dataset  2025-04-15T11:00:00+0200
# 2          LFST_HHEREDTY  dataset  2025-04-15T11:00:00+0200
# 3           LFST_HHINDED  dataset  2025-04-15T11:00:00+0200
# 4           LFST_HHINDWS  dataset  2025-04-15T11:00:00+0200
#
#   last table structure change data start data end
# 0    2025-04-15T11:00:00+0200       None     None
# 1    2025-04-15T11:00:00+0200       None     None
# 2    2025-04-15T11:00:00+0200       2006     2024
# 3    2025-04-15T11:00:00+0200       2006     2024
# 4    2025-04-15T11:00:00+0200       2006     2024

# %%
df_ds.dtypes
# Out:
# title                          object
# code                           object
# type                           object
# last update of data            object
# last table structure change    object
# data start                     object
# data end                       object
# dtype: object

# %%
df_ds.describe()
# Out:
#                                     title                     code     type  \
# count                                8058                     8058     8058
# unique                               7337                     8058        1
# top     Individuals - internet activities  POST_CUBE1_X$POST_DTR_1  dataset
# freq                                    6                        1     8058
#
#              last update of data last table structure change data start  \
# count                       8058                        8058       7517
# unique                       787                         419        193
# top     2025-04-30T11:00:00+0200    2024-01-03T23:00:00+0100       2005
# freq                         576                        1524        599
#
#        data end
# count      7517
# unique      102
# top        2024
# freq       1548

# %% [markdown]
# ## Set column data types

# %%
df_ds['title'] = df_ds['title'].astype('str')
df_ds['code'] = df_ds['code'].astype('str')
df_ds['last update of data'] = convert_to_datetime(df_ds['last update of data'])
df_ds['last table structure change'] = convert_to_datetime(df_ds['last table structure change'])

# %%
df_ds['data start'].unique()
# Out:
# array([None, '2006', '2021', '1995', '2008', '2003', '1999', '1992',
#        '1997', '2001', '2002', '2013', '2000', '2014', '1998', '2005',
#        '2019', '2004', '2018', '1997-Q1', '2001-Q1', '2000-Q1', '2003-Q1',
#        '2005-Q1', '2007-Q1', '2009-Q1', '2011-Q1', '2013-Q1', '2015-Q1',
#        '2017-Q1', '2019-Q1', '2021-Q1', '2023-Q1', '2004-Q1', '2002-Q1',
#        '1998-Q1', '2018-Q1', '2008-Q1', '2011', '2010', '2012', '2009',
#        '2020', '2023', '2024-04', '2007', '1960', '1980', '1995-Q1',
#        '1993', '1985', '1990', '1995-Q4', '1996', '2015', '1994',
#        '1996-Q1', '2014-Q1', '1977', '1990-01', '2021-01', '2022',
#        '2008-01', '1950', '2019-S2', '2022-Q1', '1986', '1988', '1999-01',
#        '2002-01', '1978', '2016', '2022-03', '2018-01', '1975', '1994-Q1',
#        '2017', '1975-Q1', '1949', '1952-Q1', '1947-Q1', '2019-01',
#        '2023-11', '1991', '1992-Q2', '1983-01', '1992-Q1', '1989',
#        '1980-Q1', '1978-Q1', '1979', '1998-Q4', '1999-Q1', '2005-01',
#        '1983', '1979-01', '1994-01', '1995-01', '1989-Q4', '1954',
#        '1980-01', '1953-Q4', '1993-01', '1962', '1962-01', '1962-Q1',
#        '2007-S1', '1975-01', '1985-S1', '1976', '1976-01', '1976-Q1',
#        '1953', '1953-01', '1953-Q1', '1990-Q1', '2015-01', '2000-01',
#        '2010-01', '2010-Q1', '1991-01', '1991-Q1', '1991-S2', '2013-01',
#        '2022-Q2', '2024-03', '2024-05', '2022-Q3', '1970', '2000-07',
#        '2004-S1', '2010-S1', '1994-S1', '2003-01', '2002-02', '1996-01',
#        '1997-01', '1996-02', '1997-12', '2006-Q1', '2014-S2', '1983-S2',
#        '2004-S2', '1982', '2024-02', '2015-W01', '1989-Q1', '2003-Q2',
#        '2004-09-06', '2004-09', '2004-Q3', '1973', '1973-01', '1973-Q1',
#        '1970-01', '1970-Q1', '1999-01-04', '2011-01', '1981', '1987',
#        '1980-01-01', '2024', '2019-Q4', '2020-Q1', '1982-Q1', '2020-01',
#        '2000-W01', '1999-S1', '1992-Q4', '1981-Q1', '1985-01', '2006-04',
#        '2007-Q3', '1984-02', '1988-01', '2001-Q2', '1980-02', '1991-02',
#        '2000-02', '1969', '1969-01', '1971', '1971-01', '1971-Q1',
#        '1974-07-01', '1967', '1967-01', '1968', '1968-01', '1959',
#        '1993-S1', '1950-01', '2009-09', '1984'], dtype=object)

# %%
df_ds[['start_year','start_quater']] = df_ds['data start'].str.split('-',n=1,expand=True)
df_ds[['end_year','end_quater']] = df_ds['data end'].str.split('-',n=1,expand=True)
df_ds['start_year'] = pd.to_numeric(df_ds['start_year'], errors='coerce')
df_ds['end_year'] = pd.to_numeric(df_ds['end_year'], errors='coerce')
df_ds = df_ds.drop(columns=['data start', 'data end'])

# %%
unique_start = df_ds['start_year'].unique()
unique_start.sort()
unique_start
# Out:
# array([1947., 1949., 1950., 1952., 1953., 1954., 1959., 1960., 1962.,
#        1967., 1968., 1969., 1970., 1971., 1973., 1974., 1975., 1976.,
#        1977., 1978., 1979., 1980., 1981., 1982., 1983., 1984., 1985.,
#        1986., 1987., 1988., 1989., 1990., 1991., 1992., 1993., 1994.,
#        1995., 1996., 1997., 1998., 1999., 2000., 2001., 2002., 2003.,
#        2004., 2005., 2006., 2007., 2008., 2009., 2010., 2011., 2012.,
#        2013., 2014., 2015., 2016., 2017., 2018., 2019., 2020., 2021.,
#        2022., 2023., 2024.,   nan])

# %%
unique_start = df_ds['end_year'].unique()
unique_start.sort()
unique_start
# Out:
# array([1983., 1984., 1991., 1995., 1996., 1997., 1998., 1999., 2000.,
#        2001., 2002., 2003., 2004., 2005., 2006., 2007., 2008., 2009.,
#        2010., 2011., 2012., 2013., 2014., 2015., 2016., 2017., 2018.,
#        2019., 2020., 2021., 2022., 2023., 2024., 2025., 2026., 2032.,
#        2050., 2100.,   nan])

# %%
df_ds.describe(include = 'all')
# Out:
#                                     title                     code     type  \
# count                                8058                     8058     8058
# unique                               7337                     8058        1
# top     Individuals - internet activities  POST_CUBE1_X$POST_DTR_1  dataset
# freq                                    6                        1     8058
# mean                                  NaN                      NaN      NaN
# min                                   NaN                      NaN      NaN
# 25%                                   NaN                      NaN      NaN
# 50%                                   NaN                      NaN      NaN
# 75%                                   NaN                      NaN      NaN
# max                                   NaN                      NaN      NaN
# std                                   NaN                      NaN      NaN
#
#                         last update of data  \
# count                                  8058
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean    2022-06-22 00:38:33.203772672+00:00
# min               2009-03-26 10:00:00+00:00
# 25%               2021-10-12 09:00:00+00:00
# 50%               2024-12-13 10:00:00+00:00
# 75%               2025-04-14 21:00:00+00:00
# max               2025-05-05 09:00:00+00:00
# std                                     NaN
#
#                 last table structure change   start_year start_quater  \
# count                                  8058  7517.000000          723
# unique                                  NaN          NaN           20
# top                                     NaN          NaN           Q1
# freq                                    NaN          NaN          359
# mean    2024-08-16 08:17:21.722015232+00:00  2005.709991          NaN
# min               2018-12-13 12:00:00+00:00  1947.000000          NaN
# 25%               2024-01-03 22:00:00+00:00  2000.000000          NaN
# 50%               2024-10-15 09:00:00+00:00  2007.000000          NaN
# 75%               2025-03-27 22:00:00+00:00  2014.000000          NaN
# max               2025-05-05 09:00:00+00:00  2024.000000          NaN
# std                                     NaN    12.078122          NaN
#
#            end_year end_quater
# count   7517.000000        827
# unique          NaN         21
# top             NaN         Q4
# freq            NaN        304
# mean    2019.142610        NaN
# min     1983.000000        NaN
# 25%     2016.000000        NaN
# 50%     2022.000000        NaN
# 75%     2024.000000        NaN
# max     2100.000000        NaN
# std        8.653885        NaN

# %% [markdown]
# ## Dataset cleanup  and relevance filtring

# %%
df_ds = df_ds.drop(columns='type')

# %%
df_title_duplicates = df_ds[df_ds.duplicated(subset='title',keep=False)]
df_title_duplicates
# Out:
#                                                                                                                              title  \
# 0     Employment rate of adults by sex, age groups, educational attainment level, number of children and age of youngest child (%)
# 1     Employment rate of adults by sex, age groups, educational attainment level, number of children and age of youngest child (%)
# 6                              Number of households by household composition, number of children and age of youngest child (1 000)
# 7                              Number of households by household composition, number of children and age of youngest child (1 000)
# 8                   Number of households by household composition, number of children and working status within households (1 000)
# ...                                                                                                                            ...
# 7922                                                                                                        Employment rate by sex
# 7924                                                                                            Long-term unemployment rate by sex
# 7941                                                                                                            Soil sealing index
# 7944                                                                                             Recycling rate of municipal waste
# 7948                                                                                                    Circular material use rate
#
#                        code       last update of data  \
# 0     LFST_HHEREDCH$DV_1904 2025-04-15 09:00:00+00:00
# 1     LFST_HHEREDCH$DV_2683 2025-04-15 09:00:00+00:00
# 6             LFST_HHNHTYCH 2025-04-15 09:00:00+00:00
# 7     LFST_HHNHTYCH$DV_2142 2025-04-15 09:00:00+00:00
# 8             LFST_HHNHWHTC 2025-04-15 09:00:00+00:00
# ...                     ...                       ...
# 7922              SDG_08_30 2025-04-14 21:00:00+00:00
# 7924              SDG_08_40 2025-03-13 22:00:00+00:00
# 7941              SDG_11_32 2024-06-11 21:00:00+00:00
# 7944              SDG_11_60 2025-02-13 10:00:00+00:00
# 7948              SDG_12_41 2024-11-13 10:00:00+00:00
#
#      last table structure change  start_year start_quater  end_year end_quater
# 0      2025-04-15 09:00:00+00:00         NaN         None       NaN       None
# 1      2025-04-15 09:00:00+00:00         NaN         None       NaN       None
# 6      2025-04-15 09:00:00+00:00      2006.0         None    2024.0       None
# 7      2025-04-15 09:00:00+00:00         NaN         None       NaN       None
# 8      2025-04-15 09:00:00+00:00      2006.0         None    2024.0       None
# ...                          ...         ...          ...       ...        ...
# 7922   2025-04-14 21:00:00+00:00      2009.0         None    2024.0       None
# 7924   2025-03-13 22:00:00+00:00      2009.0         None    2024.0       None
# 7941   2025-01-23 22:00:00+00:00      2006.0         None    2018.0       None
# 7944   2025-02-13 10:00:00+00:00      2000.0         None    2023.0       None
# 7948   2024-11-13 10:00:00+00:00      2004.0         None    2023.0       None
#
# [1285 rows x 8 columns]

# %% [markdown]
# It looks like datasets with duplicates titles include at least one version that has a $DV suffix followed by number.
# This indicates a derived veiw (or data variation), which is not relevant for the purpose of this project.
#
# Therefore, I will exclude these derived view from the list of available datasets.

# %%
df_ds[df_ds['code'].str.contains('\\$DV', na = False)]
# Out:
#                                                                                                                              title  \
# 0     Employment rate of adults by sex, age groups, educational attainment level, number of children and age of youngest child (%)
# 1     Employment rate of adults by sex, age groups, educational attainment level, number of children and age of youngest child (%)
# 7                              Number of households by household composition, number of children and age of youngest child (1 000)
# 9                   Number of households by household composition, number of children and working status within households (1 000)
# 11                   Percentage of part-time employment of adults by sex, age groups, number of children and age of youngest child
# ...                                                                                                                            ...
# 7862                                                              Industry by employment size class (NACE Rev. 2, B-E) (2005-2020)
# 7864                                              Enterprise statistics by size class and NACE Rev. 2 activity (from 2021 onwards)
# 7865                                              Enterprise statistics by size class and NACE Rev. 2 activity (from 2021 onwards)
# 7866                                              Enterprise statistics by size class and NACE Rev. 2 activity (from 2021 onwards)
# 7868                        Annual enterprise statistics by size class for special aggregates of NACE Rev.2 activities (2005-2020)
#
#                        code       last update of data  \
# 0     LFST_HHEREDCH$DV_1904 2025-04-15 09:00:00+00:00
# 1     LFST_HHEREDCH$DV_2683 2025-04-15 09:00:00+00:00
# 7     LFST_HHNHTYCH$DV_2142 2025-04-15 09:00:00+00:00
# 9     LFST_HHNHWHTC$DV_1623 2025-04-15 09:00:00+00:00
# 11    LFST_HHPTECHI$DV_1903 2025-04-15 09:00:00+00:00
# ...                     ...                       ...
# 7862   SBS_SC_IND_R2$DV_665 2024-03-01 22:00:00+00:00
# 7864     SBS_SC_OVW$DV_1482 2025-04-07 21:00:00+00:00
# 7865     SBS_SC_OVW$DV_1601 2025-04-07 21:00:00+00:00
# 7866     SBS_SC_OVW$DV_2302 2025-04-07 21:00:00+00:00
# 7868   SBS_SC_SCA_R2$DV_342 2024-03-01 22:00:00+00:00
#
#      last table structure change  start_year start_quater  end_year end_quater
# 0      2025-04-15 09:00:00+00:00         NaN         None       NaN       None
# 1      2025-04-15 09:00:00+00:00         NaN         None       NaN       None
# 7      2025-04-15 09:00:00+00:00         NaN         None       NaN       None
# 9      2025-04-15 09:00:00+00:00         NaN         None       NaN       None
# 11     2025-04-15 09:00:00+00:00         NaN         None       NaN       None
# ...                          ...         ...          ...       ...        ...
# 7862   2023-12-21 22:00:00+00:00         NaN         None       NaN       None
# 7864   2025-04-07 21:00:00+00:00         NaN         None       NaN       None
# 7865   2025-04-07 21:00:00+00:00         NaN         None       NaN       None
# 7866   2025-04-07 21:00:00+00:00         NaN         None       NaN       None
# 7868   2023-12-21 22:00:00+00:00         NaN         None       NaN       None
#
# [449 rows x 8 columns]

# %%
df_ds = df_ds[~df_ds['code'].str.contains('\\$DV', na = False)]

# %% [markdown]
# There are two types of naming:
# 1. {domain}_{specific area} as example LFSA = labour force survey + Annual
# 2. {domain}{number}, as example TIPSII40 = International investment position (tipsii) + number

# %%
df_ds[['domain','ds_name']] = df_ds['code'].apply(split_domain).apply(pd.Series)

# %%
df_ds['domain'] = df_ds['domain'].astype('category')

# %% [markdown]
# Duplicate dataset titles are still present, indicating that further analysis is needed to fully resolve and filter out all redundant entries.

# %%
df_title_duplicates = df_ds[df_ds.duplicated(subset='title',keep=False)]
df_title_duplicates.sort_values('title')
# Out:
#                                                                        title  \
# 5834                   Active population by sex, age and citizenship (1 000)
# 4954                   Active population by sex, age and citizenship (1 000)
# 5832  Active population by sex, age and educational attainment level (1 000)
# 4952  Active population by sex, age and educational attainment level (1 000)
# 5845                          Activity rates by sex, age and citizenship (%)
# ...                                                                      ...
# 3843     Unemployment rates by sex, age and educational attainment level (%)
# 2125                           Volume of passenger transport relative to GDP
# 1482                           Volume of passenger transport relative to GDP
# 7162                                                       Water use balance
# 796                                                        Water use balance
#
#                code       last update of data last table structure change  \
# 5834      LFSA_AGAN 2025-04-14 21:00:00+00:00   2025-04-14 21:00:00+00:00
# 4954      LFSQ_AGAN 2025-03-25 22:00:00+00:00   2025-03-14 10:00:00+00:00
# 5832     LFSA_AGAED 2025-04-14 21:00:00+00:00   2025-04-14 21:00:00+00:00
# 4952     LFSQ_AGAED 2025-03-25 22:00:00+00:00   2025-03-14 10:00:00+00:00
# 5845     LFSA_ARGAN 2025-04-14 21:00:00+00:00   2025-04-14 21:00:00+00:00
# ...             ...                       ...                         ...
# 3843    LFSA_URGAED 2025-04-14 21:00:00+00:00   2025-04-14 21:00:00+00:00
# 2125       TTR00001 2024-07-25 21:00:00+00:00   2025-01-23 22:00:00+00:00
# 1482  TRAN_HV_PSTRA 2024-07-25 21:00:00+00:00   2024-07-25 21:00:00+00:00
# 7162    ENV_WAT_BAL 2024-07-08 09:00:00+00:00   2024-07-08 09:00:00+00:00
# 796        MED_EN42 2020-05-28 21:00:00+00:00   2024-01-10 22:00:00+00:00
#
#       start_year start_quater  end_year end_quater    domain   ds_name
# 5834      1995.0         None    2024.0       None      LFSA      AGAN
# 4954      1998.0           Q1    2024.0         Q4      LFSQ      AGAN
# 5832      1983.0         None    2024.0       None      LFSA     AGAED
# 4952      1998.0           Q1    2024.0         Q4      LFSQ     AGAED
# 5845      1995.0         None    2024.0       None      LFSA     ARGAN
# ...          ...          ...       ...        ...       ...       ...
# 3843      1983.0         None    2024.0       None      LFSA    URGAED
# 2125      2011.0         None    2022.0       None  TTR00001       NaN
# 1482      1990.0         None    2022.0       None      TRAN  HV_PSTRA
# 7162      1970.0         None    2022.0       None       ENV   WAT_BAL
# 796       2005.0         None    2018.0       None       MED      EN42
#
# [493 rows x 10 columns]

# %%
df_same_name = df_title_duplicates.groupby(['ds_name'])['title'].count().reset_index(name='count')
df_same_name = df_same_name[df_same_name['count']>1]
exclude_from_duplicates = set(df_title_duplicates[df_title_duplicates['ds_name'].isin(df_same_name['ds_name'])].sort_values('ds_name')['code'])
df_title_duplicates['not_duplicate'] = df_title_duplicates['code'].apply(lambda x: x in exclude_from_duplicates )
# Out:
# /tmp/ipykernel_4476/3274389406.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title_duplicates['not_duplicate'] = df_title_duplicates['code'].apply(lambda x: x in exclude_from_duplicates )

# %% [markdown]
# By looking at docs there are 2 types of statistics annual and quater.
# Because this project about storing data the both of them are going to be stored in same area but in different files.
#
# Additionally there are derived tables that have the same title, but was not marked properly.
# * Volume of passenger transport relative to GDP 	TTR00001 	- derived
# * Volume of passenger transport relative to GDP 	TRAN_HV_PSTRA
#
# But at the same time there are data sets that start with TTR and not derived

# %%
df_title_duplicates[df_title_duplicates['not_duplicate']==False].sort_values('title')
# Out:
#                                                                                   title  \
# 4185  Aggregate replacement ratio for pensions (excluding other social benefits) by sex
# 2715  Aggregate replacement ratio for pensions (excluding other social benefits) by sex
# 1500                                          Air transport of freight by NUTS 2 region
# 378                                           Air transport of freight by NUTS 2 region
# 1502                                       Air transport of passengers by NUTS 2 region
# ...                                                                                 ...
# 3719                                                           Unemployment rate by sex
# 1482                                      Volume of passenger transport relative to GDP
# 2125                                      Volume of passenger transport relative to GDP
# 7162                                                                  Water use balance
# 796                                                                   Water use balance
#
#                 code       last update of data last table structure change  \
# 4185        TESPN070 2025-04-30 09:00:00+00:00   2025-04-30 09:00:00+00:00
# 2715        ILC_PNP3 2025-04-30 09:00:00+00:00   2025-01-27 22:00:00+00:00
# 1500  TRAN_R_AVGO_NM 2024-05-05 21:00:00+00:00   2024-08-29 09:00:00+00:00
# 378         TGS00078 2024-08-29 09:00:00+00:00   2025-01-23 22:00:00+00:00
# 1502  TRAN_R_AVPA_NM 2024-05-05 21:00:00+00:00   2024-08-29 09:00:00+00:00
# ...              ...                       ...                         ...
# 3719        TEILM020 2025-05-02 09:00:00+00:00   2025-04-04 09:00:00+00:00
# 1482   TRAN_HV_PSTRA 2024-07-25 21:00:00+00:00   2024-07-25 21:00:00+00:00
# 2125        TTR00001 2024-07-25 21:00:00+00:00   2025-01-23 22:00:00+00:00
# 7162     ENV_WAT_BAL 2024-07-08 09:00:00+00:00   2024-07-08 09:00:00+00:00
# 796         MED_EN42 2020-05-28 21:00:00+00:00   2024-01-10 22:00:00+00:00
#
#       start_year start_quater  end_year end_quater    domain    ds_name  \
# 4185      2010.0         None    2024.0       None  TESPN070        NaN
# 2715      2010.0         None    2024.0       None       ILC       PNP3
# 1500      1993.0         None    2022.0       None      TRAN  R_AVGO_NM
# 378       2011.0         None    2022.0       None  TGS00078        NaN
# 1502      1993.0         None    2022.0       None      TRAN  R_AVPA_NM
# ...          ...          ...       ...        ...       ...        ...
# 3719      2024.0           04    2025.0         03  TEILM020        NaN
# 1482      1990.0         None    2022.0       None      TRAN   HV_PSTRA
# 2125      2011.0         None    2022.0       None  TTR00001        NaN
# 7162      1970.0         None    2022.0       None       ENV    WAT_BAL
# 796       2005.0         None    2018.0       None       MED       EN42
#
#       not_duplicate
# 4185          False
# 2715          False
# 1500          False
# 378           False
# 1502          False
# ...             ...
# 3719          False
# 1482          False
# 2125          False
# 7162          False
# 796           False
#
# [359 rows x 11 columns]

# %% [markdown]
# Looks like in general all dataset with underscore in their name contains raw or structured data.
#
# Flat codes often contains pre-aggregated or simplified data.
#
# So if the dataset have the same title, but one of entries no underscore then it is likely to be derived.
# If both have underscode both saved
# If no one have underscore they should be cheched.

# %%
def determine_duplicate(row, df : pd.DataFrame):
    if row['not_duplicate']:
        return True
    if '_' in row['code']:
        return True
    df_same_title : pd.DataFrame = df[df['title']==row['title']]
    # 
    has_underscore = df_same_title['code'].str.contains('_').any()
    if has_underscore:
        return False
    return True
    
df_title_duplicates['not_duplicate'] = df_title_duplicates.apply(lambda row: determine_duplicate(row,df_title_duplicates),axis=1)
df_title_duplicates[df_title_duplicates['not_duplicate']].count()
# Out:
# /tmp/ipykernel_4476/2812439347.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title_duplicates['not_duplicate'] = df_title_duplicates.apply(lambda row: determine_duplicate(row,df_title_duplicates),axis=1)
# title                          455
# code                           455
# last update of data            455
# last table structure change    455
# start_year                     455
# start_quater                    83
# end_year                       455
# end_quater                      83
# domain                         455
# ds_name                        447
# not_duplicate                  455
# dtype: int64

# %%
df_title_duplicates[df_title_duplicates['not_duplicate']==False].sort_values('title')
# Out:
#                                                                                             title  \
# 4185            Aggregate replacement ratio for pensions (excluding other social benefits) by sex
# 378                                                     Air transport of freight by NUTS 2 region
# 377                                                  Air transport of passengers by NUTS 2 region
# 364                                                           Animal populations by NUTS 2 region
# 383                                                      At-risk-of-poverty rate by NUTS 2 region
# 374                                                  Available beds in hospitals by NUTS 2 region
# 757                                                                Building permits - annual data
# 3692                                                              Building permits - monthly data
# 3252                                               EMU convergence criterion series - annual data
# 3382                                                            Employment expectations indicator
# 4121                                                                       Employment rate by sex
# 4010                                        Environmental protection investments of total economy
# 4019                                                                   Environmental tax revenues
# 3989                                                           Final energy consumption by sector
# 620                                                            Financial account - quarterly data
# 4148                                                            Gender pay gap in unadjusted form
# 1370                                                           Healthy life years at birth by sex
# 3561                                              House price index (2015 = 100) - quarterly data
# 3362                                           International investment position - quarterly data
# 4143                                                           Long-term unemployment rate by sex
# 376                                                Maritime transport of freight by NUTS 2 region
# 375                                             Maritime transport of passengers by NUTS 2 region
# 390                         Nights spent at tourist accommodation establishments by NUTS 2 region
# 498                                                          Nights spent by duration of the trip
# 400                              Percentage change of value added by ICT sector at current prices
# 396                                             Percentage of the ICT sector in Gross value added
# 398                                    Percentage of the ICT sector personnel in total employment
# 365                                            Production of cow's milk on farms by NUTS 2 region
# 855                                                                           Real GDP per capita
# 384                                             Severe material deprivation rate by NUTS 2 region
# 3163  Share of irrigable and irrigated areas in utilised agricultural area (UAA) by NUTS 2 region
# 3167                Share of main land types in utilised agricultural area (UAA) by NUTS 2 region
# 3169                Share of main livestock types in total livestock units (LSU) by NUTS 2 region
# 4152                                             Tax rate on low wage earners - Unemployment trap
# 494                                    Trips by detailed country/world region of main destination
# 491                                                                 Trips by duration of the trip
# 489                                                                              Trips by purpose
# 2125                                                Volume of passenger transport relative to GDP
#
#           code       last update of data last table structure change  \
# 4185  TESPN070 2025-04-30 09:00:00+00:00   2025-04-30 09:00:00+00:00
# 378   TGS00078 2024-08-29 09:00:00+00:00   2025-01-23 22:00:00+00:00
# 377   TGS00077 2024-08-29 09:00:00+00:00   2025-01-23 22:00:00+00:00
# 364   TGS00045 2025-03-27 22:00:00+00:00   2025-03-27 22:00:00+00:00
# 383   TGS00103 2025-04-30 09:00:00+00:00   2025-04-30 09:00:00+00:00
# 374   TGS00064 2024-09-03 21:00:00+00:00   2025-01-23 22:00:00+00:00
# 757   TIPSHO50 2025-05-05 09:00:00+00:00   2025-04-14 21:00:00+00:00
# 3692  TEIIS550 2025-05-05 09:00:00+00:00   2025-04-15 09:00:00+00:00
# 3252  TEC00097 2025-01-15 10:00:00+00:00   2025-01-15 10:00:00+00:00
# 3382  TEIBS030 2025-04-29 09:00:00+00:00   2025-04-29 09:00:00+00:00
# 4121  TESEM010 2025-04-14 21:00:00+00:00   2025-04-14 21:00:00+00:00
# 4010  TEN00136 2025-03-31 21:00:00+00:00   2025-03-31 21:00:00+00:00
# 4019  TEN00141 2025-01-28 10:00:00+00:00   2025-01-28 10:00:00+00:00
# 3989  TEN00124 2025-05-02 21:00:00+00:00   2024-12-16 10:00:00+00:00
# 620   TIPSBP48 2025-04-11 21:00:00+00:00   2025-04-11 21:00:00+00:00
# 4148  TESEM180 2025-02-25 10:00:00+00:00   2025-02-25 10:00:00+00:00
# 1370  TPS00150 2024-06-11 21:00:00+00:00   2025-01-23 22:00:00+00:00
# 3561  TEICP270 2025-04-08 09:00:00+00:00   2025-04-08 09:00:00+00:00
# 3362  TEIBP041 2025-04-11 21:00:00+00:00   2025-04-11 21:00:00+00:00
# 4143  TESEM130 2025-03-13 22:00:00+00:00   2025-03-13 22:00:00+00:00
# 376   TGS00076 2024-08-29 09:00:00+00:00   2025-01-23 22:00:00+00:00
# 375   TGS00075 2024-08-29 09:00:00+00:00   2025-01-23 22:00:00+00:00
# 390   TGS00111 2025-04-29 09:00:00+00:00   2025-04-29 09:00:00+00:00
# 498   TIN00192 2025-02-27 22:00:00+00:00   2025-02-27 22:00:00+00:00
# 400   TIN00086 2025-04-04 21:00:00+00:00   2025-04-04 21:00:00+00:00
# 396   TIN00074 2025-03-20 22:00:00+00:00   2025-03-20 22:00:00+00:00
# 398   TIN00085 2025-03-20 22:00:00+00:00   2025-03-20 22:00:00+00:00
# 365   TGS00046 2024-10-07 21:00:00+00:00   2025-01-23 22:00:00+00:00
# 855   TIPSNA40 2025-05-02 21:00:00+00:00   2025-04-14 21:00:00+00:00
# 384   TGS00104 2025-03-21 22:00:00+00:00   2025-03-21 22:00:00+00:00
# 3163     TAI03 2024-01-03 22:00:00+00:00   2025-01-23 22:00:00+00:00
# 3167     TAI05 2024-01-03 22:00:00+00:00   2025-01-23 22:00:00+00:00
# 3169     TAI06 2024-01-03 22:00:00+00:00   2025-01-23 22:00:00+00:00
# 4152  TESEM220 2025-04-29 21:00:00+00:00   2025-04-29 21:00:00+00:00
# 494   TIN00190 2025-02-27 22:00:00+00:00   2025-02-27 22:00:00+00:00
# 491   TIN00189 2025-02-27 22:00:00+00:00   2025-02-27 22:00:00+00:00
# 489   TIN00188 2025-02-27 22:00:00+00:00   2025-02-27 22:00:00+00:00
# 2125  TTR00001 2024-07-25 21:00:00+00:00   2025-01-23 22:00:00+00:00
#
#       start_year start_quater  end_year end_quater    domain ds_name  \
# 4185      2010.0         None    2024.0       None  TESPN070     NaN
# 378       2011.0         None    2022.0       None  TGS00078     NaN
# 377       2011.0         None    2022.0       None  TGS00077     NaN
# 364       2013.0         None    2024.0       None  TGS00045     NaN
# 383       2013.0         None    2024.0       None  TGS00103     NaN
# 374       2011.0         None    2022.0       None  TGS00064     NaN
# 757       2005.0         None    2024.0       None  TIPSHO50     NaN
# 3692      2024.0           04    2025.0         03  TEIIS550     NaN
# 3252      2013.0         None    2024.0       None  TEC00097     NaN
# 3382      2024.0           05    2025.0         04  TEIBS030     NaN
# 4121      2005.0         None    2024.0       None  TESEM010     NaN
# 4010      2012.0         None    2023.0       None  TEN00136     NaN
# 4019      2012.0         None    2023.0       None  TEN00141     NaN
# 3989      2012.0         None    2023.0       None  TEN00124     NaN
# 620       1995.0           Q1    2024.0         Q4  TIPSBP48     NaN
# 4148      2007.0         None    2023.0       None  TESEM180     NaN
# 1370      2011.0         None    2022.0       None  TPS00150     NaN
# 3561      2022.0           Q1    2024.0         Q4  TEICP270     NaN
# 3362      2022.0           Q1    2024.0         Q4  TEIBP041     NaN
# 4143      2005.0         None    2024.0       None  TESEM130     NaN
# 376       2011.0         None    2022.0       None  TGS00076     NaN
# 375       2011.0         None    2022.0       None  TGS00075     NaN
# 390       2013.0         None    2024.0       None  TGS00111     NaN
# 498       2012.0         None    2023.0       None  TIN00192     NaN
# 400       2011.0         None    2022.0       None  TIN00086     NaN
# 396       2011.0         None    2022.0       None  TIN00074     NaN
# 398       2011.0         None    2022.0       None  TIN00085     NaN
# 365       2012.0         None    2023.0       None  TGS00046     NaN
# 855       1995.0         None    2024.0       None  TIPSNA40     NaN
# 384       2009.0         None    2020.0       None  TGS00104     NaN
# 3163      2005.0         None    2016.0       None     TAI03     NaN
# 3167      2005.0         None    2016.0       None     TAI05     NaN
# 3169      2005.0         None    2016.0       None     TAI06     NaN
# 4152      2005.0         None    2024.0       None  TESEM220     NaN
# 494       2012.0         None    2023.0       None  TIN00190     NaN
# 491       2012.0         None    2023.0       None  TIN00189     NaN
# 489       2012.0         None    2023.0       None  TIN00188     NaN
# 2125      2011.0         None    2022.0       None  TTR00001     NaN
#
#       not_duplicate
# 4185          False
# 378           False
# 377           False
# 364           False
# 383           False
# 374           False
# 757           False
# 3692          False
# 3252          False
# 3382          False
# 4121          False
# 4010          False
# 4019          False
# 3989          False
# 620           False
# 4148          False
# 1370          False
# 3561          False
# 3362          False
# 4143          False
# 376           False
# 375           False
# 390           False
# 498           False
# 400           False
# 396           False
# 398           False
# 365           False
# 855           False
# 384           False
# 3163          False
# 3167          False
# 3169          False
# 4152          False
# 494           False
# 491           False
# 489           False
# 2125          False

# %%
df_ds = df_ds[~df_ds['code'].isin(df_title_duplicates[df_title_duplicates['not_duplicate']==False])]

# %%
df_ds.describe(include='all')
# Out:
#                                                                                                                    title  \
# count                                                                                                               7609
# unique                                                                                                              7337
# top     Hourly earnings by economic activity and contractual working time (enterprises with 10 employed persons or more)
# freq                                                                                                                   4
# mean                                                                                                                 NaN
# min                                                                                                                  NaN
# 25%                                                                                                                  NaN
# 50%                                                                                                                  NaN
# 75%                                                                                                                  NaN
# max                                                                                                                  NaN
# std                                                                                                                  NaN
#
#                            code                  last update of data  \
# count                      7609                                 7609
# unique                     7609                                  NaN
# top     POST_CUBE1_X$POST_DTR_1                                  NaN
# freq                          1                                  NaN
# mean                        NaN  2022-05-09 14:47:38.009725184+00:00
# min                         NaN            2009-03-26 10:00:00+00:00
# 25%                         NaN            2021-04-26 21:00:00+00:00
# 50%                         NaN            2024-12-12 22:00:00+00:00
# 75%                         NaN            2025-04-14 21:00:00+00:00
# max                         NaN            2025-05-05 09:00:00+00:00
# std                         NaN                                  NaN
#
#                 last table structure change   start_year start_quater  \
# count                                  7609  7517.000000          723
# unique                                  NaN          NaN           20
# top                                     NaN          NaN           Q1
# freq                                    NaN          NaN          359
# mean    2024-08-13 23:42:19.597318912+00:00  2005.709991          NaN
# min               2018-12-13 12:00:00+00:00  1947.000000          NaN
# 25%               2024-01-03 22:00:00+00:00  2000.000000          NaN
# 50%               2024-10-15 09:00:00+00:00  2007.000000          NaN
# 75%               2025-03-27 22:00:00+00:00  2014.000000          NaN
# max               2025-05-05 09:00:00+00:00  2024.000000          NaN
# std                                     NaN    12.078122          NaN
#
#            end_year end_quater domain  ds_name
# count   7517.000000        827   7609     6823
# unique          NaN         21    888     6624
# top             NaN         Q4    ILC  10_F_BS
# freq            NaN        304    501        4
# mean    2019.142610        NaN    NaN      NaN
# min     1983.000000        NaN    NaN      NaN
# 25%     2016.000000        NaN    NaN      NaN
# 50%     2022.000000        NaN    NaN      NaN
# 75%     2024.000000        NaN    NaN      NaN
# max     2100.000000        NaN    NaN      NaN
# std        8.653885        NaN    NaN      NaN

# %%
df_ds['end_year'].unique()
# Out:
# array([2024., 2023., 2008., 2019., 2022., 1999., 2002., 2004., 2006.,
#        2010., 2012., 2014., 2016., 2018., 2020., 2021., 2025., 2003.,
#        2015., 2013., 2011., 2017., 2007., 2005., 2001., 2009., 2100.,
#        2000., 1996., 2032., 2050.,   nan, 1998., 1997., 1991., 1995.,
#        2026., 1983., 1984.])

# %% [markdown]
# # Check na values

# %%
(df_ds.isna().sum()/len(df_ds))*100
# Out:
# title                           0.000000
# code                            0.000000
# last update of data             0.000000
# last table structure change     0.000000
# start_year                      1.209094
# start_quater                   90.498094
# end_year                        1.209094
# end_quater                     89.131292
# domain                          0.000000
# ds_name                        10.329873
# dtype: float64

# %%
df_ds.isna().value_counts()
# Out:
# title  code   last update of data  last table structure change  start_year  start_quater  end_year  end_quater  domain  ds_name
# False  False  False                False                        False       True          False     True        False   False      6121
#                                                                                                                         True        569
#                                                                             False         False     False       False   False       516
#                                                                                                                         True        207
#                                                                             True          False     False       False   False       104
#                                                                 True        True          True      True        False   False        82
#                                                                                                                         True         10
# Name: count, dtype: int64

# %%
def setDomain(row):
    match = re.match(r"^([a-zA-Z]+)(_|-)?(.*)",row['code'])
    if match:
        gr2 = match.group(3)
        if gr2:
            return match.group(1),gr2
        else:
            return match.group(1), None
    return row['domain'],row['ds_name']

# %%
df_ds[['domain','ds_name']] = df_ds.apply(lambda row: pd.Series(setDomain(row)),axis=1)

# %%
df_ds.isna().value_counts()
# Out:
# title  code   last update of data  last table structure change  start_year  start_quater  end_year  end_quater  domain  ds_name
# False  False  False                False                        False       True          False     True        False   False      6690
#                                                                             False         False     False       False   False       723
#                                                                             True          False     False       False   False       104
#                                                                 True        True          True      True        False   False        92
# Name: count, dtype: int64

# %%
df_ds[df_ds[['start_year', 'start_quater', 'end_year', 'end_quater']].isna().all(axis=1)]
# Out:
#                                                                                                                    title  \
# 3932                                                                           Water resources: long-term annual average
# 7168                                                          Renewable freshwater resources - long term annual averages
# 7957                                                                                    EU trade since 2017 by BEC/rev.5
# 7958                                                                                    EU trade since 2002 by BEC/rev.4
# 7959                                                                                                    Total production
# ...                                                                                                                  ...
# 8052                               Prices of letter mail  and parcel services (USP under direct or indirect designation)
# 8053  Postal services falling under the universal service obligation (USP under direct or indirect designation, traffic)
# 8055                                                                     Number of enterprises providing postal services
# 8056                                                          Access points  (USP under direct or indirect designation )
# 8057                                                            Domestic postal traffic, letter mail and parcel services
#
#                          code       last update of data  \
# 3932                 TEN00001 2024-07-05 21:00:00+00:00
# 7168             ENV_WAT_LTAA 2024-07-05 21:00:00+00:00
# 7957                DS-059329 2025-04-23 09:00:00+00:00
# 7958                DS-059328 2025-04-23 09:00:00+00:00
# 7959                DS-056121 2025-02-06 10:00:00+00:00
# ...                       ...                       ...
# 8052  POST_CUBE1_X$POST_PRI_1 2025-04-15 12:44:56+00:00
# 8053      POST_CUBE1_X$USO701 2025-04-15 12:44:56+00:00
# 8055      POST_CUBE1_X$NUM701 2025-04-15 12:44:56+00:00
# 8056  POST_CUBE1_X$POST_ACC_1 2025-04-15 12:44:56+00:00
# 8057  POST_CUBE1_X$POST_DTR_1 2025-04-15 12:44:56+00:00
#
#      last table structure change  start_year start_quater  end_year  \
# 3932   2024-07-05 21:00:00+00:00         NaN         None       NaN
# 7168   2023-07-31 21:00:00+00:00         NaN         None       NaN
# 7957   2025-04-23 09:00:00+00:00         NaN         None       NaN
# 7958   2025-04-23 09:00:00+00:00         NaN         None       NaN
# 7959   2025-02-06 10:00:00+00:00         NaN         None       NaN
# ...                          ...         ...          ...       ...
# 8052   2025-04-15 12:44:56+00:00         NaN         None       NaN
# 8053   2025-04-15 12:44:56+00:00         NaN         None       NaN
# 8055   2025-04-15 12:44:56+00:00         NaN         None       NaN
# 8056   2025-04-15 12:44:56+00:00         NaN         None       NaN
# 8057   2025-04-15 12:44:56+00:00         NaN         None       NaN
#
#      end_quater domain             ds_name
# 3932       None    TEN               00001
# 7168       None    ENV            WAT_LTAA
# 7957       None     DS              059329
# 7958       None     DS              059328
# 7959       None     DS              056121
# ...         ...    ...                 ...
# 8052       None   POST  CUBE1_X$POST_PRI_1
# 8053       None   POST      CUBE1_X$USO701
# 8055       None   POST      CUBE1_X$NUM701
# 8056       None   POST  CUBE1_X$POST_ACC_1
# 8057       None   POST  CUBE1_X$POST_DTR_1
#
# [92 rows x 10 columns]

# %% [markdown]
# Most of the datasets without any data about start and end are providing some summary analitical data, so they do not manupulate time period data.
#
# Start and end quater are available only if data set has any data period data.
